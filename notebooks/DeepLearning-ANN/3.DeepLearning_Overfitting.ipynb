# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 종양 데이터 특성 값을 통해 악성종양 여부 Classification

# %%
df = pd.read_csv('https://raw.githubusercontent.com/song9063/Wiset2025Examples/refs/heads/main/datasets/cancer_classification.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
sns.countplot(x='benign_0__mal_1', data=df)
# Out:
# <Axes: xlabel='benign_0__mal_1', ylabel='count'>

# %%
df.corr()
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.323782        0.997855   0.987357
# mean texture                0.323782      1.000000        0.329533   0.321086
# mean perimeter              0.997855      0.329533        1.000000   0.986507
# mean area                   0.987357      0.321086        0.986507   1.000000
# mean smoothness             0.170581     -0.023389        0.207278   0.177028
# mean compactness            0.506124      0.236702        0.556936   0.498502
# mean concavity              0.676764      0.302418        0.716136   0.685983
# mean concave points         0.822529      0.293464        0.850977   0.823269
# mean symmetry               0.147741      0.071401        0.183027   0.151293
# mean fractal dimension     -0.311631     -0.076437       -0.261477  -0.283110
# radius error                0.679090      0.275869        0.691765   0.732562
# ...

# %%
df.corr()['benign_0__mal_1'].sort_values().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
# 학습데이터 만들기, X, y, -> X_train,X_test,.....
X = df.drop('benign_0__mal_1', axis=1).values
y = df['benign_0__mal_1'].values

# %%
# 훈련, 테스트
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    random_state=1234
)

# %%
# Scale 조정
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
# scaler.fit(X_train)
# X_train = scaler.transform(X_train)
X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
# Model 만들기

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout

# %%
# X_train.shape
model = Sequential()

# Input layer
model.add( Dense(30, activation='relu') )

# Hidden layer
model.add( Dense(15, activation='relu') )

# Output layer
# Bianary Classification: sigmoid
model.add( Dense(1, activation='sigmoid') )

model.compile(
    loss='binary_crossentropy',
    optimizer='adam'
)

# %%
# 학습해라
model.fit(
    x=X_train, y=y_train,
    validation_data=(X_test, y_test),
    epochs=600
)

# %%
losses = pd.DataFrame(model.history.history)

# %%
losses.plot()
# Out:
# <Axes: >

# %%
# X_train.shape
model = Sequential()

# Input layer
model.add( Dense(30, activation='relu') )

# Hidden layer
model.add( Dense(15, activation='relu') )

# Output layer
# Bianary Classification: sigmoid
model.add( Dense(1, activation='sigmoid') )

model.compile(
    loss='binary_crossentropy',
    optimizer='adam'
)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
e_stop = EarlyStopping(
    monitor='val_loss',
    mode='min',
    patience=25
)

# %%
model.fit(
    x=X_train, y=y_train,
    validation_data=(X_test, y_test),
    epochs=600,
    callbacks=[ e_stop ]
)
# Out:
# Epoch 1/600
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - loss: 0.6933 - val_loss: 0.6466
# Epoch 2/600
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.6378 - val_loss: 0.6002
# Epoch 3/600
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.5962 - val_loss: 0.5582
# Epoch 4/600
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.5493 - val_loss: 0.5137
# Epoch 5/600
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4984 - val_loss: 0.4666
# Epoch 6/600
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4380 - val_loss: 0.4176
# Epoch 7/600
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3876 - val_loss: 0.3808
# Epoch 8/600
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3370 - val_loss: 0.3489
# Epoch 9/600
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3042 - val_loss: 0.3180
# Epoch 10/600
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2629 - val_loss: 0.3044
# Epoch 11/600
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2432 - val_loss: 0.2870
# Epoch 12/600
# ...

# %%
# X_train.shape
model = Sequential()

# Input layer
model.add( Dense(30, activation='relu') )
model.add( Dropout(0.5) ) # <---

# Hidden layer
model.add( Dense(15, activation='relu') )
model.add( Dropout(0.5) ) # <---

# Output layer
# Bianary Classification: sigmoid
model.add( Dense(1, activation='sigmoid') )

model.compile(
    loss='binary_crossentropy',
    optimizer='adam'
)

# %%
model.fit(
    x=X_train, y=y_train,
    validation_data=(X_test, y_test),
    epochs=600,
    callbacks=[e_stop]
)

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %%
losses = pd.DataFrame(model.history.history)
losses.plot()
# Out:
# <Axes: >

# %%
preds = (model.predict(X_test) > 0.5).astype("int32")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(y_test, preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.91      0.95        45
#            1       0.95      1.00      0.97        69
#
#     accuracy                           0.96       114
#    macro avg       0.97      0.96      0.96       114
# weighted avg       0.97      0.96      0.96       114

# %%
print(confusion_matrix(y_test, preds))
# Out:
# [[41  4]
#  [ 0 69]]
